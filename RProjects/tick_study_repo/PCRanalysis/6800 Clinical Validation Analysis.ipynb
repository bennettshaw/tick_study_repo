# %%
setwd("~/Desktop/Tick Research")
install.packages("ggplot2")
library("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
babclinval <- read.csv("6800_clin_val_coded.csv")

# %%
plot(babclinval$babct~babclinval$parasit)
# Out:
# plot without title

# %%
ggplot(babclinval, aes(diag_clean, babct)) + geom_boxplot(aes(fill=diag_clean)) + theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(babclinval, aes(diag_clean, babrfi)) + geom_boxplot(aes(fill=diag_clean)) + theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(babclinval, aes(diag_clean, ipcct)) + geom_boxplot(aes(fill=diag_clean)) + theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(babclinval, aes(diag_clean, ipcrfi)) + geom_boxplot(aes(fill=diag_clean)) + theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(babclinval, aes(babrfi, ipcrfi)) + geom_point(aes(color=diagnosis))
# Out:
# plot without title

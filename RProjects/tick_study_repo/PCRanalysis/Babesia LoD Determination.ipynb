# %%
setwd("~/Desktop/Tick Research")
install.packages("ggplot2")
library("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
pt <- read.csv("bab_pt_sample_dilution.csv")

# %%
ggplot(pt, aes(Conc, babct)) + geom_point() + geom_boxplot(aes(fill=Conc))
# Out:
# plot without title

# %%
gb <- read.csv("bab_gblock_dilution.csv")
gb$conc.factor <- as.factor(gb$Conc)

# %%
ggplot(gb, aes(conc.factor, babct)) + geom_point(aes(color=conc.factor))
# Out:
# plot without title

# %%
gb$logcopyn <- log10(gb$Conc)
print(gb)
# Out:
#        Conc babct babrfi ipcct ipcrfi conc.factor    logcopyn
# 1  0.00e+00  0.00   0.00 33.64  11.06           0        -Inf
# 2  1.00e+05 17.40   8.50 33.77  12.66       1e+05  5.00000000
# 3  1.00e+05 17.31   8.56 33.54  12.79       1e+05  5.00000000
# 4  1.00e+05 17.40   8.67 33.52  13.05       1e+05  5.00000000
# 5  1.00e+04 20.91   8.38 33.50  12.74       10000  4.00000000
# 6  1.00e+04 20.75   8.39 33.60  12.91       10000  4.00000000
# 7  1.00e+04 20.55   8.27 33.44  12.93       10000  4.00000000
# 8  1.00e+03 24.39   8.14 33.50  13.30        1000  3.00000000
# 9  1.00e+03 24.62   8.23 33.35  13.49        1000  3.00000000
# 10 1.00e+03 24.60   8.30 33.72  13.26        1000  3.00000000
# 11 1.00e+02 28.23   7.74 34.33  13.75         100  2.00000000
# 12 1.00e+02 28.01   7.63 33.23  13.67         100  2.00000000
# 13 1.00e+02 28.25   7.56 33.87  13.29         100  2.00000000
# 14 1.00e+01 32.50   6.14 33.97  12.53          10  1.00000000
# ...

# %%
std <- gb[2:22,]
print(std)
# Out:
#        Conc babct babrfi ipcct ipcrfi conc.factor   logcopyn
# 2  1.00e+05 17.40   8.50 33.77  12.66       1e+05 5.00000000
# 3  1.00e+05 17.31   8.56 33.54  12.79       1e+05 5.00000000
# 4  1.00e+05 17.40   8.67 33.52  13.05       1e+05 5.00000000
# 5  1.00e+04 20.91   8.38 33.50  12.74       10000 4.00000000
# 6  1.00e+04 20.75   8.39 33.60  12.91       10000 4.00000000
# 7  1.00e+04 20.55   8.27 33.44  12.93       10000 4.00000000
# 8  1.00e+03 24.39   8.14 33.50  13.30        1000 3.00000000
# 9  1.00e+03 24.62   8.23 33.35  13.49        1000 3.00000000
# 10 1.00e+03 24.60   8.30 33.72  13.26        1000 3.00000000
# 11 1.00e+02 28.23   7.74 34.33  13.75         100 2.00000000
# 12 1.00e+02 28.01   7.63 33.23  13.67         100 2.00000000
# 13 1.00e+02 28.25   7.56 33.87  13.29         100 2.00000000
# 14 1.00e+01 32.50   6.14 33.97  12.53          10 1.00000000
# 15 1.00e+01 32.65   6.14 33.76  14.47          10 1.00000000
# ...

# %%
ggplot(std, aes(babct, logcopyn)) + geom_point() + geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
bablm <- lm(std$babct~std$logcopyn)
summary(bablm)
# Out:
# Call:
# lm(formula = std$babct ~ std$logcopyn)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.93689 -0.26130 -0.07242  0.30535  0.74982
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  36.08906    0.14901  242.20   <2e-16 ***
# std$logcopyn -3.79888    0.05303  -71.64   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4174 on 19 degrees of freedom
# Multiple R-squared:  0.9963,	Adjusted R-squared:  0.9961
# F-statistic:  5133 on 1 and 19 DF,  p-value: < 2.2e-16

# %%
x=3.79/3.3
print (x)
# Out:
# [1] 1.148485

# %%
#114% efficiency

# %%
ggplot(pt, aes(Conc, babrfi)) + geom_point() + geom_boxplot(aes(fill=Conc))
# Out:
# plot without title

# %%
ggplot(pt, aes(Conc, ipcct)) + geom_point() + geom_boxplot(aes(fill=Conc))
# Out:
# plot without title

# %%
ggplot(pt, aes(Conc, ipcrfi)) + geom_point() + geom_boxplot(aes(fill=Conc))
# Out:
# plot without title

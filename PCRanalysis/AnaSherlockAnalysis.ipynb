# %%
setwd("~/Desktop/Tick Research")
install.packages("ggplot2")
library("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
catana <- read.csv("catana.csv")

# %%
catana$logcopyn <- log10(catana$copyn)

# %%
print(catana)
# Out:
#    ctstd copyn logcopyn
# 1 37.954     1  0.00000
# 2 36.016     5  0.69897
# 3 35.798    10  1.00000
# 4 32.276   100  2.00000
# 5 28.455  1000  3.00000
# 6 25.168 10000  4.00000
# 7 35.106    NA       NA
# 8 35.613    NA       NA

# %%
std <- catana[1:6,]
print (std)
# Out:
#    ctstd copyn logcopyn
# 1 37.954     1  0.00000
# 2 36.016     5  0.69897
# 3 35.798    10  1.00000
# 4 32.276   100  2.00000
# 5 28.455  1000  3.00000
# 6 25.168 10000  4.00000

# %%
ggplot(std, aes(std$ctstd,std$logcopyn)) + geom_point() + geom_smooth(method=lm)
# Out:
# plot without title

# %%
lm1 <- lm(catana$ctstd~catana$logcopyn)

# %%
summary(lm1)
print(lm1)
# Out:
# Call:
# lm(formula = catana$ctstd ~ catana$logcopyn)
#
# Residuals:
#       1       2       3       4       5       6
# -0.4931 -0.1435  0.6237  0.3745 -0.1737 -0.1878
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      38.4471     0.3092  124.36 2.51e-08 ***
# catana$logcopyn  -3.2728     0.1371  -23.86 1.83e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4633 on 4 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.993,	Adjusted R-squared:  0.9913
# F-statistic: 569.5 on 1 and 4 DF,  p-value: 1.829e-05
# Call:
# lm(formula = catana$ctstd ~ catana$logcopyn)
#
# Coefficients:
#     (Intercept)  catana$logcopyn
#          38.447           -3.273

# %%
lm2 <- lm(catana$logcopyn~catana$ctstd)
summary(lm2)
# Out:
# Call:
# lm(formula = catana$logcopyn ~ catana$ctstd)
#
# Residuals:
#        1        2        3        4        5        6
# -0.16206 -0.05111  0.18377  0.11514 -0.04421 -0.04153
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  11.67789    0.41861   27.90 9.82e-06 ***
# catana$ctstd -0.30342    0.01271  -23.86 1.83e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1411 on 4 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.993,	Adjusted R-squared:  0.9913
# F-statistic: 569.5 on 1 and 4 DF,  p-value: 1.829e-05

# %%
catana$logpredict <- predict.lm(lm2,catana)

# %%
print(catana)
# Out:
#    ctstd copyn logcopyn logpredict
# 1 37.954     1  0.00000  0.1620645
# 2 36.016     5  0.69897  0.7500833
# 3 35.798    10  1.00000  0.8162278
# 4 32.276   100  2.00000  1.8848563
# 5 28.455  1000  3.00000  3.0442060
# 6 25.168 10000  4.00000  4.0415320
# 7 35.106    NA       NA  1.0261912
# 8 35.613    NA       NA  0.8723596

# %%
catana$copynpred <- 10^(catana$logpredict)

# %%
print(catana)
# Out:
#    ctstd copyn logcopyn logpredict    copynpred
# 1 37.954     1  0.00000  0.1620645     1.452327
# 2 36.016     5  0.69897  0.7500833     5.624492
# 3 35.798    10  1.00000  0.8162278     6.549797
# 4 32.276   100  2.00000  1.8848563    76.710771
# 5 28.455  1000  3.00000  3.0442060  1107.148900
# 6 25.168 10000  4.00000  4.0415320 11003.528522
# 7 35.106    NA       NA  1.0261912    10.621630
# 8 35.613    NA       NA  0.8723596     7.453489
